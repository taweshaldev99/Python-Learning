# %%
#Bar Plot
import matplotlib.pyplot as plt
import numpy as np
import random

x= np.random.randint(10,60,(50))    #gives data from 10-60 where n=50
print(x)
# Out:
# [40 16 10 13 59 11 21 25 35 15 49 43 22 40 30 41 11 17 10 33 33 57 18 29
#  48 40 49 58 43 27 59 44 38 30 46 32 25 48 48 51 12 11 29 29 16 10 55 13
#  53 53]

# %%
no= [17, 14, 51, 15, 57, 23, 54, 56, 22, 46, 26, 57, 41, 58, 26, 13, 45, 13, 32, 53, 56, 19, 49, 41,
 58 ,37, 14, 32, 12, 45, 39, 41, 31, 48, 43, 26, 53, 19 ,29 ,46 ,25 ,24, 45, 21, 32 ,31 ,51, 27,
 47, 48]
l=[10,20,30,40,50,60]
plt.hist(no,color="b",bins=l,edgecolor="r")
plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No")
plt.show()

# %%
no= [17, 14, 51, 15, 57, 23, 54, 56, 22, 46, 26, 57, 41, 58, 26, 13, 45, 13, 32, 53, 56, 19, 49, 41,
 58 ,37, 14, 32, 12, 45, 39, 41, 31, 48, 43, 26, 53, 19 ,29 ,46 ,25 ,24, 45, 21, 32 ,31 ,51, 27,
 47, 48]
l=[10,20,30,40,50,60]
plt.hist(no,"auto",(0,100),edgecolor="r")
plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No")
plt.show()
# Out:
# /tmp/ipython-input-84552633.py:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(no,"auto",(0,100),edgecolor="r")

# %%
no= [17, 14, 51, 15, 57, 23, 54, 56, 22, 46, 26, 57, 41, 58, 26, 13, 45, 13, 32, 53, 56, 19, 49, 41,
 58 ,37, 14, 32, 12, 45, 39, 41, 31, 48, 43, 26, 53, 19 ,29 ,46 ,25 ,24, 45, 21, 32 ,31 ,51, 27,
 47, 48]
l=[10,20,30,40,50,60]
plt.hist(no,color="b",bins=l,edgecolor="r",cumulative=-1,bottom=10,align="mid",histtype="step",orientation="horizontal")     #CUMULATIVE =Reverse garxa

plt.title("Histogram")                                                  # bottom = mention gare bata start hunxa
plt.xlabel("Python")
plt.ylabel("No")
plt.show()

# %%
no= [17, 14, 51, 15, 57, 23, 54, 56, 22, 46, 26, 57, 41, 58, 26, 13, 45, 13, 32, 53, 56, 19, 49, 41,
 58 ,37, 14, 32, 12, 45, 39, 41, 31, 48, 43, 26, 53, 19 ,29 ,46 ,25 ,24, 45, 21, 32 ,31 ,51, 27,
 47, 48]
l=[10,20,30,40,50,60]
plt.hist(no,color="b",bins=l,edgecolor="r",rwidth=0.8,log=True,label="MATPLOT")
plt.title("Histogram")
plt.xlabel("Python")

plt.axvline(45,color="red",label="line")

plt.legend()
plt.ylabel("No")
plt.grid()
plt.show()
