# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline

# %%
#generate random numbers =10
randomNumber = np.random.rand(10)

# %%
#view them
print(randomNumber)
# Out:
# [0.09348507 0.20212364 0.56020425 0.75291845 0.58359846 0.01347989
#  0.05622919 0.6848853  0.96103906 0.31543373]

# %%
#select the style of the plot
style.use('ggplot')

# %%
#plotting and display
plt.plot(randomNumber,'g',label='line one',linewidth=2)
plt.xlabel('Range')
plt.ylabel('Numbers')
plt.title('First Plot')
plt.legend()
plt.show()
